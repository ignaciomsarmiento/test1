# %%
import matplotlib.pyplot as plt
#import mplleaflet
import pandas as pd
import numpy as np

# %%
def leaflet_plot_stations(binsize, hashid):
    
    # load source data 
    df = pd.read_csv('data/C2A2_data/BinSize_d{}.csv'.format(binsize))
    
    temp = pd.read_csv('data/C2A2_data/BinnedCsvs_d400/fb441e62df2d58994928907a91895ec62c2c42e6cd075c2700843b89.csv'.format(binsize))
    
    
    df_temp = pd.DataFrame(temp)
    
    # over-over write df, on condition df['hash' == hashid]
    station_locations_by_hash = df[df['hash'] == hashid]

    # get coordinates to list,  to  x,y values 
    lons = station_locations_by_hash['LONGITUDE'].tolist()
    lats = station_locations_by_hash['LATITUDE'].tolist()
    
    # plot figure 
    plt.figure(figsize=(8,8))
    
    # plot scatter plot. parameters: x_values=lons, y_values=lats, c='r' color red, alpha(transparency)=0.7, s(size)=200 
    plt.scatter(lons, lats, c='r', alpha=0.7, s=200)
    
    mplleaflet.display()
    
    # create temperatures value functions, x-values and y-values
    y_tmax = []
    date_max = []
    
    y_tmin = []
    date_min = []
    
    dates = []
    
    # create date strings threshold
    
    # set 2005-2014
    date_2005_start = '2005-01-01'
    date_2005_end = '2005-12-31'
    date_2014_end = '2014-12-31'
    
    # set 2005-2015 max values
    temp_max = None #0
    temp_min = None #0
    
    # df_temp = df_temp['2005-01-01'<=df_temp['Date'].to_datetime<'2014-01-01']
    
    # convert df_temp['Date'] dates into datetime format
    df_temp['Date'] = pd.to_datetime(df_temp['Date'] )
    aux1 = df_temp['Date']
    
    
    #aux1 = []
    #for date in df_temp['Date']:
    #    date_actual = pd.to_datetime(date) 
    #    aux1.append(date_actual)    
    
    
    # for index, row in df_temp.iterrows():,  iterate through rows in DataFrame
    for index, row in df_temp.iterrows():
        
        # if row['Date] between date_2005_start - date_2014_end, 
        if pd.to_datetime(date_2005_start)<=row['Date']<= pd.to_datetime(date_2014_end):
            # append to list of dates
            dates.append(row['Date'])
            
            # add values to TMAX-TMIN y values, with respective date x values
            if row['Element'] == "TMAX":
                y_tmax.append(row['Data_Value'])
                date_max.append(row['Date'])
                
            elif row['Element'] == "TMIN":
                y_tmin.append(row['Data_Value'])
                date_min.append(row['Date'])
            
            else:
                pass
        else:
            pass
        
        # set temp_max, temp_min from max/min list
        temp_max = np.max(y_tmax)
        #temp_min = np.min(y_tmin)

        
    
    
    
    # create figure
    plt.figure()
    
    
    # plt.show()
    
    
    print(type(aux1) )
    return aux1


leaflet_plot_stations(400,'fb441e62df2d58994928907a91895ec62c2c42e6cd075c2700843b89')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1900/1912507755.py in <module>
#      98
#      99
# --> 100 leaflet_plot_stations(400,'fb441e62df2d58994928907a91895ec62c2c42e6cd075c2700843b89')
#
# ~\AppData\Local\Temp/ipykernel_1900/1912507755.py in leaflet_plot_stations(binsize, hashid)
#       2
#       3     # load source data
# ----> 4     df = pd.read_csv('data/C2A2_data/BinSize_d{}.csv'.format(binsize))
#       5
#       6     temp = pd.read_csv('data/C2A2_data/BinnedCsvs_d400/fb441e62df2d58994928907a91895ec62c2c42e6cd075c2700843b89.csv'.format(binsize))
#
# ...
